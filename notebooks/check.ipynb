# %%
import os
import numpy as np
import pandas as pd

# =========================
# CONFIG
# =========================

DATA_TYPE = "ADP"  # change to "MSB" or "MBC" to compare

TRANSFORMATIONS_NOT_HUMAN = [
    "rawSN","pcaSN","degSN","degRandSN","degPCA_SN",
    "scviSN","scvi_LSshift_SN","degScviSN","degScviLSshift_SN"
]
TRANSFORMATIONS_HUMAN = [
    "rawSN","pcaSN","degSN","degIntSN","degRandSN","degOtherSN",
    "degPCA_SN","scviSN","scvi_LSshift_SN","degScviSN","degScviLSshift_SN"
]

IS_HUMAN = (DATA_TYPE != "MSB")
TRANSFORMATIONS = TRANSFORMATIONS_HUMAN if IS_HUMAN else TRANSFORMATIONS_NOT_HUMAN

BASE_REFS = ["sc_raw", "sn_raw", "degIntAllSN"]

ROOT = os.path.abspath(os.path.join(os.getcwd(), "scripts"))
IMPORT_PATH = os.path.abspath(os.path.join(ROOT, "../../", "data", "deconvolution", DATA_TYPE))
MIXTURE_FILE = os.path.join(IMPORT_PATH, "pseudobulks.csv")

print("IMPORT_PATH:", IMPORT_PATH)
print("MIXTURE_FILE:", MIXTURE_FILE)

def load_mixture(path):
    mix = pd.read_csv(path, index_col=0)
    print("Loaded mixture_data:", mix.shape)
    return mix

def basic_value_stats_sample(mat: pd.DataFrame, max_sample=300_000):
    vals = mat.to_numpy().astype(float).ravel()
    vals = vals[np.isfinite(vals)]
    if vals.size == 0:
        return dict(min=np.nan, max=np.nan, mean=np.nan,
                    frac_lt1=np.nan, frac_nonint=np.nan,
                    any_negative=False, any_nan=False, any_inf=False)
    if vals.size > max_sample:
        idx = np.random.choice(vals.size, size=max_sample, replace=False)
        vals = vals[idx]
    stats = {
        "min": float(vals.min()),
        "max": float(vals.max()),
        "mean": float(vals.mean()),
        "frac_lt1": float((vals < 1).mean()),
        "frac_nonint": float((vals != np.round(vals)).mean()),
        "any_negative": bool((vals < 0).any()),
        "any_nan": bool(np.isnan(vals).any()),
        "any_inf": bool(np.isinf(vals).any()),
    }
    return stats

def looks_like_log_or_heavy_norm(stats, log_max=20, high_frac_lt1=0.8):
    if np.isnan(stats["max"]):
        return True
    if stats["any_negative"] or stats["any_nan"] or stats["any_inf"]:
        return True
    if stats["max"] < log_max and stats["frac_lt1"] > high_frac_lt1:
        return True
    return False

def check_reference(mixture_df, signal_path, cell_state_path, ref_name):
    info = {
        "ref": ref_name,
        "signal_exists": os.path.exists(signal_path),
        "cell_state_exists": os.path.exists(cell_state_path),
        "ok": True,
        "reason": [],
        "n_genes_overlap": 0,
        "n_cells": np.nan,
        "stats_min": np.nan,
        "stats_max": np.nan,
        "stats_mean": np.nan,
        "stats_frac_lt1": np.nan,
        "stats_frac_nonint": np.nan,
        "looks_logish": np.nan,
        "labels_match_cells": np.nan,
        "transform": None,
    }

    if not info["signal_exists"] or not info["cell_state_exists"]:
        info["ok"] = False
        info["reason"].append("missing signal or cell_state file")
        return info

    try:
        signal_df = pd.read_csv(signal_path, index_col=0)
    except Exception as e:
        info["ok"] = False
        info["reason"].append(f"failed to load signal: {e}")
        return info

    try:
        anno_df = pd.read_csv(cell_state_path)
    except Exception as e:
        info["ok"] = False
        info["reason"].append(f"failed to load cell_state: {e}")
        return info

    # Gene intersection
    common_genes = mixture_df.index.intersection(signal_df.index)
    info["n_genes_overlap"] = len(common_genes)
    if len(common_genes) < 500:
        info["ok"] = False
        info["reason"].append(f"<500 overlapping genes ({len(common_genes)})")

    if len(common_genes) == 0:
        info["ok"] = False
        info["reason"].append("no overlapping genes")
        return info

    signal_sub = signal_df.loc[common_genes]
    info["n_cells"] = signal_sub.shape[1]

    # Value stats
    stats = basic_value_stats_sample(signal_sub)
    info["stats_min"] = stats["min"]
    info["stats_max"] = stats["max"]
    info["stats_mean"] = stats["mean"]
    info["stats_frac_lt1"] = stats["frac_lt1"]
    info["stats_frac_nonint"] = stats["frac_nonint"]
    info["looks_logish"] = looks_like_log_or_heavy_norm(stats)

    if stats["any_negative"]:
        info["ok"] = False
        info["reason"].append("negative values in signal")
    if stats["any_nan"] or stats["any_inf"]:
        info["ok"] = False
        info["reason"].append("NaN/Inf values in signal")
    if info["looks_logish"]:
        info["reason"].append("values look log-ish / heavily normalized")

    # Annotation
    if "cell_type" not in anno_df.columns:
        info["ok"] = False
        info["reason"].append("cell_state has no 'cell_type' column")
        return info

    labels = anno_df["cell_type"].astype(str)
    if len(labels) != signal_sub.shape[1]:
        info["ok"] = False
        info["reason"].append(f"len(cell_type)={len(labels)} != n_cells={signal_sub.shape[1]}")
        info["labels_match_cells"] = False
    else:
        info["labels_match_cells"] = True

    return info

# =========================
# Run checks
# =========================

mixture_df = load_mixture(MIXTURE_FILE)
results = []

# Base refs
for base_ref in BASE_REFS:
    sig_file = os.path.join(IMPORT_PATH, f"{base_ref}_signal.csv")
    anno_file = os.path.join(IMPORT_PATH, f"{base_ref}_cell_state.csv")
    info = check_reference(mixture_df, sig_file, anno_file, ref_name=base_ref)
    info["transform"] = "base"
    results.append(info)

# Cell types from sc_raw_cell_state.csv
sc_raw_cell_state_file = os.path.join(IMPORT_PATH, "sc_raw_cell_state.csv")
if os.path.exists(sc_raw_cell_state_file):
    sc_raw_cell_state = pd.read_csv(sc_raw_cell_state_file)
    unique_cell_types = sorted(sc_raw_cell_state["cell_type"].unique())
else:
    unique_cell_types = []

# All transforms
for ct in unique_cell_types:
    ct_clean = str(ct).replace(" ", "_")
    for trans in TRANSFORMATIONS:
        ref_prefix = f"ref_{ct_clean}_{trans}"
        sig_file = os.path.join(IMPORT_PATH, f"{ref_prefix}_signal.csv")
        anno_file = os.path.join(IMPORT_PATH, f"{ref_prefix}_cell_state.csv")
        info = check_reference(mixture_df, sig_file, anno_file, ref_name=ref_prefix)
        info["transform"] = trans
        results.append(info)

results_df = pd.DataFrame(results)

results_df["ok_flag"] = results_df["ok"].astype(int)
results_df = results_df.sort_values(
    by=["transform", "ok_flag", "n_genes_overlap", "n_cells"],
    ascending=[True, False, False, False]
)

pd.set_option("display.max_rows", 300)
pd.set_option("display.max_colwidth", 200)

print("\n===== SUMMARY OF ALL TRANSFORMS FOR DATA_TYPE =", DATA_TYPE, "=====\n")
display_cols = [
    "ref", "transform", "ok", "n_genes_overlap", "n_cells",
    "stats_min", "stats_max", "stats_mean",
    "stats_frac_lt1", "stats_frac_nonint",
    "looks_logish", "labels_match_cells", "reason"
]
display(results_df[display_cols])
# Out:
# IMPORT_PATH: /projects/aivich@xsede.org/deconvolution_sc_sn_comparison/data/deconvolution/ADP
# MIXTURE_FILE: /projects/aivich@xsede.org/deconvolution_sc_sn_comparison/data/deconvolution/ADP/pseudobulks.csv
# Loaded mixture_data: (28129, 1000)
#
# ===== SUMMARY OF ALL TRANSFORMS FOR DATA_TYPE = ADP =====
#                                           ref          transform    ok  \
# 0                                      sc_raw               base  True
# 1                                      sn_raw               base  True
# 2                                 degIntAllSN               base  True
# 61                 ref_Preadipocytes_degIntSN           degIntSN  True
# 39                   ref_Macrophages_degIntSN           degIntSN  True
# 17             ref_Endothelial_Cells_degIntSN           degIntSN  True
# 6                ref_Dendritic_Cells_degIntSN           degIntSN  True
# 28           ref_Immature_NK_T_Cells_degIntSN           degIntSN  True
# 50                     ref_Monocytes_degIntSN           degIntSN  True
# 72                       ref_T_Cells_degIntSN           degIntSN  True
# 63               ref_Preadipocytes_degOtherSN         degOtherSN  True
# 41                 ref_Macrophages_degOtherSN         degOtherSN  True
# 19           ref_Endothelial_Cells_degOtherSN         degOtherSN  True
# 8              ref_Dendritic_Cells_degOtherSN         degOtherSN  True
# 30         ref_Immature_NK_T_Cells_degOtherSN         degOtherSN  True
# 52                   ref_Monocytes_degOtherSN         degOtherSN  True
# 74                     ref_T_Cells_degOtherSN         degOtherSN  True
# 64                ref_Preadipocytes_degPCA_SN          degPCA_SN  True
# 42                  ref_Macrophages_degPCA_SN          degPCA_SN  True
# 9               ref_Dendritic_Cells_degPCA_SN          degPCA_SN  True
# 75                      ref_T_Cells_degPCA_SN          degPCA_SN  True
# 31          ref_Immature_NK_T_Cells_degPCA_SN          degPCA_SN  True
# 53                    ref_Monocytes_degPCA_SN          degPCA_SN  True
# 20            ref_Endothelial_Cells_degPCA_SN          degPCA_SN  True
# 62                ref_Preadipocytes_degRandSN          degRandSN  True
# 40                  ref_Macrophages_degRandSN          degRandSN  True
# 7               ref_Dendritic_Cells_degRandSN          degRandSN  True
# 73                      ref_T_Cells_degRandSN          degRandSN  True
# 29          ref_Immature_NK_T_Cells_degRandSN          degRandSN  True
# 51                    ref_Monocytes_degRandSN          degRandSN  True
# 18            ref_Endothelial_Cells_degRandSN          degRandSN  True
# 60                    ref_Preadipocytes_degSN              degSN  True
# 38                      ref_Macrophages_degSN              degSN  True
# 5                   ref_Dendritic_Cells_degSN              degSN  True
# 71                          ref_T_Cells_degSN              degSN  True
# 27              ref_Immature_NK_T_Cells_degSN              degSN  True
# 49                        ref_Monocytes_degSN              degSN  True
# 16                ref_Endothelial_Cells_degSN              degSN  True
# 68        ref_Preadipocytes_degScviLSshift_SN  degScviLSshift_SN  True
# 46          ref_Macrophages_degScviLSshift_SN  degScviLSshift_SN  True
# 13      ref_Dendritic_Cells_degScviLSshift_SN  degScviLSshift_SN  True
# 79              ref_T_Cells_degScviLSshift_SN  degScviLSshift_SN  True
# 35  ref_Immature_NK_T_Cells_degScviLSshift_SN  degScviLSshift_SN  True
# 57            ref_Monocytes_degScviLSshift_SN  degScviLSshift_SN  True
# 24    ref_Endothelial_Cells_degScviLSshift_SN  degScviLSshift_SN  True
# 67                ref_Preadipocytes_degScviSN          degScviSN  True
# 45                  ref_Macrophages_degScviSN          degScviSN  True
# 12              ref_Dendritic_Cells_degScviSN          degScviSN  True
# 78                      ref_T_Cells_degScviSN          degScviSN  True
# 34          ref_Immature_NK_T_Cells_degScviSN          degScviSN  True
# 56                    ref_Monocytes_degScviSN          degScviSN  True
# 23            ref_Endothelial_Cells_degScviSN          degScviSN  True
# 59                    ref_Preadipocytes_pcaSN              pcaSN  True
# 37                      ref_Macrophages_pcaSN              pcaSN  True
# 15                ref_Endothelial_Cells_pcaSN              pcaSN  True
# 4                   ref_Dendritic_Cells_pcaSN              pcaSN  True
# 26              ref_Immature_NK_T_Cells_pcaSN              pcaSN  True
# 48                        ref_Monocytes_pcaSN              pcaSN  True
# 70                          ref_T_Cells_pcaSN              pcaSN  True
# 58                    ref_Preadipocytes_rawSN              rawSN  True
# 36                      ref_Macrophages_rawSN              rawSN  True
# 14                ref_Endothelial_Cells_rawSN              rawSN  True
# 3                   ref_Dendritic_Cells_rawSN              rawSN  True
# 25              ref_Immature_NK_T_Cells_rawSN              rawSN  True
# 47                        ref_Monocytes_rawSN              rawSN  True
# 69                          ref_T_Cells_rawSN              rawSN  True
# 65                   ref_Preadipocytes_scviSN             scviSN  True
# 43                     ref_Macrophages_scviSN             scviSN  True
# 21               ref_Endothelial_Cells_scviSN             scviSN  True
# 10                 ref_Dendritic_Cells_scviSN             scviSN  True
# 32             ref_Immature_NK_T_Cells_scviSN             scviSN  True
# 54                       ref_Monocytes_scviSN             scviSN  True
# 76                         ref_T_Cells_scviSN             scviSN  True
# 66          ref_Preadipocytes_scvi_LSshift_SN    scvi_LSshift_SN  True
# 44            ref_Macrophages_scvi_LSshift_SN    scvi_LSshift_SN  True
# 22      ref_Endothelial_Cells_scvi_LSshift_SN    scvi_LSshift_SN  True
# 11        ref_Dendritic_Cells_scvi_LSshift_SN    scvi_LSshift_SN  True
# 33    ref_Immature_NK_T_Cells_scvi_LSshift_SN    scvi_LSshift_SN  True
# 55              ref_Monocytes_scvi_LSshift_SN    scvi_LSshift_SN  True
# 77                ref_T_Cells_scvi_LSshift_SN    scvi_LSshift_SN  True
#
#     n_genes_overlap  n_cells  stats_min   stats_max  stats_mean  \
# 0             28129     2155        0.0   279.00000    0.123373
# 1             28129     2155        0.0   356.00000    0.073470
# 2             26350     2155        0.0   710.00000    0.068073
# 61            26350     4083        0.0   409.00000    0.070077
# 39            26350     3736        0.0   338.00000    0.075787
# 17            26350     3402        0.0   372.00000    0.080927
# 6             26350     2155        0.0   410.00000    0.093717
# 28            26350     2155        0.0   559.00000    0.094100
# 50            26350     2155        0.0   341.00000    0.095697
# 72            26350     2155        0.0   787.00000    0.095050
# 44            28129     3736        0.0   583.00000    0.069114
# 22            28129     3402        0.0   421.00000    0.079697
# 11            28129     2155        0.0   469.00000    0.119074
# 33            28129     2155        0.0   661.00000    0.128072
# 55            28129     2155        0.0   376.00000    0.122954
# 77            28129     2155        0.0   664.00000    0.124092
#
#     stats_frac_lt1  stats_frac_nonint  looks_logish  labels_match_cells reason
# 0         0.940687           0.000000         False                True     []
# 1         0.953487           0.000000         False                True     []
# 2         0.960973           0.000000         False                True     []
# 61        0.959623           0.000000         False                True     []
# 39        0.958753           0.000000         False                True     []
# 17        0.958223           0.000000         False                True     []
# 6         0.952050           0.000000         False                True     []
# 28        0.952307           0.000000         False                True     []
# 50        0.951997           0.000000         False                True     []
# 72        0.952030           0.000000         False                True     []
# 63        0.987507           0.000000         False                True     []
# 41        0.988247           0.000000         False                True     []
# 19        0.987533           0.000000         False                True     []
# 8         0.985153           0.000000         False                True     []
# 30        0.985580           0.000000         False                True     []
# 52        0.985207           0.000000         False                True     []
# 74        0.985573           0.000000         False                True     []
# 64        0.993480           0.594833         False                True     []
# 42        0.978050           0.336290         False                True     []
# 9         0.964927           0.026107         False                True     []
# 75        0.963520           0.043440         False                True     []
# 31        0.964430           0.044460         False                True     []
# 53        0.963513           0.019230         False                True     []
# 20        0.975267           0.264350         False                True     []
# 62        0.950967           0.000000         False                True     []
# 40        0.946840           0.000000         False                True     []
# 7         0.936967           0.000000         False                True     []
# 73        0.937760           0.000000         False                True     []
# 29        0.937537           0.000000         False                True     []
# 51        0.936727           0.000000         False                True     []
# 18        0.946147           0.000000         False                True     []
# 60        0.961753           0.000000         False                True     []
# 38        0.965197           0.000000         False                True     []
# 5         0.962917           0.000000         False                True     []
# 71        0.962620           0.000000         False                True     []
# 27        0.963627           0.000000         False                True     []
# 49        0.962497           0.000000         False                True     []
# 16        0.967837           0.000000         False                True     []
# 68        0.994357           0.839977         False                True     []
# 46        0.979453           0.472693         False                True     []
# 13        0.964167           0.036957         False                True     []
# 79        0.964200           0.060873         False                True     []
# 35        0.964560           0.064670         False                True     []
# 57        0.963143           0.027743         False                True     []
# 24        0.977167           0.383930         False                True     []
# 67        0.987317           0.838980         False                True     []
# 45        0.970030           0.472453         False                True     []
# 12        0.963723           0.037057         False                True     []
# 78        0.963077           0.061473         False                True     []
# 34        0.964100           0.064780         False                True     []
# 56        0.963477           0.027973         False                True     []
# 23        0.969890           0.384127         False                True     []
# 59        0.986027           0.614137         False                True     []
# 37        0.960763           0.354420         False                True     []
# 15        0.958013           0.282250         False                True     []
# 4         0.942857           0.027383         False                True     []
# 26        0.942800           0.047997         False                True     []
# 48        0.941890           0.020653         False                True     []
# 70        0.943517           0.045757         False                True     []
# 58        0.951463           0.000000         False                True     []
# 36        0.950543           0.000000         False                True     []
# 14        0.949893           0.000000         False                True     []
# 3         0.941767           0.000000         False                True     []
# 25        0.941833           0.000000         False                True     []
# 47        0.940567           0.000000         False                True     []
# 69        0.942427           0.000000         False                True     []
# 65        0.984513           0.840747         False                True     []
# 43        0.960540           0.472210         False                True     []
# 21        0.958933           0.383413         False                True     []
# 10        0.943010           0.037050         False                True     []
# 32        0.943693           0.063760         False                True     []
# 54        0.942333           0.028433         False                True     []
# 76        0.943027           0.060613         False                True     []
# 66        0.991980           0.840123         False                True     []
# 44        0.968510           0.472087         False                True     []
# 22        0.963457           0.381650         False                True     []
# 11        0.943813           0.036790         False                True     []
# 33        0.943880           0.064907         False                True     []
# 55        0.942627           0.027623         False                True     []
# 77        0.943050           0.061843         False                True     []

# %%
import os, glob, re

# === CONFIG: adjust if needed ===
BASE_DIR = "/projects/aivich@xsede.org/deconvolution_sc_sn_comparison"
dataset = "Real_ADP"
method = "SCDC"
mode = "perdonor"  # this is the mode that failed

# --- paths ---
DATA_PATH = os.path.join(BASE_DIR, "data", "deconvolution", dataset)
RESULTS_PATH = os.path.join(BASE_DIR, "results", dataset)

print("DATA_PATH   :", DATA_PATH)
print("RESULTS_PATH:", RESULTS_PATH)

# --- load donor_list from donors.csv (same logic as process_results.py) ---
donors_csv = os.path.join(DATA_PATH, "donors.csv")
if not os.path.exists(donors_csv):
    raise FileNotFoundError(f"donors.csv not found at {donors_csv}")

with open(donors_csv) as fh:
    donor_list = [d.strip() for d in fh.readline().split(",") if d.strip()]

print("\nDonor list loaded (first few):", donor_list[:5])
print("Total donors:", len(donor_list))

# --- valid transforms (same as your script) ---
valid_transforms = {
    "rawSN",
    "pcaSN",
    "degSN",
    "degRandSN",
    "degIntSN",
    "degOtherSN",
    "degPCA_SN",
    "degpcaSN",
    "scviSN",
    "scvi_LSshift_SN",
    "degScviSN",
    "degScviLSshift_SN",
    "degIntAllSN",
}

# --- this is your CURRENT parse_bp_filename (buggy version) ---
def parse_bp_filename_buggy(path: str, mode: str, method: str):
    fname = os.path.basename(path)
    core = re.sub(fr"_{method}_proportions\.csv$", "", fname)

    # simulation branch (not used here)
    if mode == "simulation":
        if core in {"sc_raw", "sn_raw"}:
            return None, core
        if core.startswith("ref_"):
            tail = core[4:]
            for t in valid_transforms:
                if tail.endswith("_" + t):
                    return None, t
        return None, None

    # real bulk branch (not used here)
    if mode == "real":
        if core in {"sc_raw_real", "sn_raw_real"}:
            return None, core
        if core.startswith(("sc_raw_", "sn_raw_")):
            parts = core.split("_")
            transform = "_".join(parts[:2])
            return None, transform
        if core.startswith("ref_real_"):
            trans = core[9:]
            if trans in valid_transforms:
                return None, trans
            if trans.lower() in valid_transforms:
                return None, trans.lower()
        return None, None

    # ---------- perdonor branch (this is what we're testing) ----------
    if mode == "perdonor" and core.startswith("ref_"):
        tail = core[4:]  # e.g. "Hs_SAT_01-1_degSN"
        if "_" not in tail:
            return None, None
        donor, transform = tail.split("_", 1)  # <-- THIS is the suspicious line

        print(f"DEBUG parse: fname={fname}")
        print(f"       core={core}")
        print(f"       tail={tail}")
        print(f"       donor={donor!r}, transform={transform!r}")
        print(f"       donor in donor_list? {donor in donor_list}\n")

        if donor not in donor_list:
            return None, None
        if transform in valid_transforms or transform.lower() in valid_transforms:
            transform = transform if transform in valid_transforms else transform.lower()
            return donor, transform
        return None, None

    return None, None


# --- collect files and test parsing ---
bp_files = sorted(glob.glob(os.path.join(RESULTS_PATH, f"*_{method}_proportions.csv")))
print(f"\nFound {len(bp_files)} '{method}' files.\n")

accepted = []
skipped = []

for fp in bp_files:
    donor, trans = parse_bp_filename_buggy(fp, mode=mode, method=method)
    fname = os.path.basename(fp)
    if trans is None:
        skipped.append(fname)
    else:
        accepted.append((fname, donor, trans))

print("\n=== SUMMARY ===")
print("Accepted files (parsed successfully):", len(accepted))
for fname, donor, trans in accepted[:10]:
    print(f"  OK   {fname}  -> donor={donor}, transform={trans}")

print("\nSkipped files (unrecognised):", len(skipped))
for fname in skipped[:10]:
    print(f"  SKIP {fname}")
# Out:
# DATA_PATH   : /projects/aivich@xsede.org/deconvolution_sc_sn_comparison/data/deconvolution/Real_ADP
# RESULTS_PATH: /projects/aivich@xsede.org/deconvolution_sc_sn_comparison/results/Real_ADP
#
# Donor list loaded (first few): ['Hs_SAT_12-1', 'Hs_SAT_13-1', 'Hs_SAT_266-1', 'Hs_SAT_01-1', 'Hs_SAT_02-1']
# Total donors: 12
#
# Found 158 'SCDC' files.
#
# DEBUG parse: fname=ref_Hs_SAT_01-1_degIntAllSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_01-1_degIntAllSN
#        tail=Hs_SAT_01-1_degIntAllSN
#        donor='Hs', transform='SAT_01-1_degIntAllSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_01-1_degIntSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_01-1_degIntSN
#        tail=Hs_SAT_01-1_degIntSN
#        donor='Hs', transform='SAT_01-1_degIntSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_01-1_degOtherSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_01-1_degOtherSN
#        tail=Hs_SAT_01-1_degOtherSN
#        donor='Hs', transform='SAT_01-1_degOtherSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_01-1_degPCA_SN_SCDC_proportions.csv
#        core=ref_Hs_SAT_01-1_degPCA_SN
#        tail=Hs_SAT_01-1_degPCA_SN
#        donor='Hs', transform='SAT_01-1_degPCA_SN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_01-1_degRandSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_01-1_degRandSN
#        tail=Hs_SAT_01-1_degRandSN
#        donor='Hs', transform='SAT_01-1_degRandSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_01-1_degSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_01-1_degSN
#        tail=Hs_SAT_01-1_degSN
#        donor='Hs', transform='SAT_01-1_degSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_01-1_degScviLSshift_SN_SCDC_proportions.csv
#        core=ref_Hs_SAT_01-1_degScviLSshift_SN
#        tail=Hs_SAT_01-1_degScviLSshift_SN
#        donor='Hs', transform='SAT_01-1_degScviLSshift_SN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_01-1_degScviSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_01-1_degScviSN
#        tail=Hs_SAT_01-1_degScviSN
#        donor='Hs', transform='SAT_01-1_degScviSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_01-1_pcaSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_01-1_pcaSN
#        tail=Hs_SAT_01-1_pcaSN
#        donor='Hs', transform='SAT_01-1_pcaSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_01-1_rawSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_01-1_rawSN
#        tail=Hs_SAT_01-1_rawSN
#        donor='Hs', transform='SAT_01-1_rawSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_01-1_scviSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_01-1_scviSN
#        tail=Hs_SAT_01-1_scviSN
#        donor='Hs', transform='SAT_01-1_scviSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_01-1_scvi_LSshift_SN_SCDC_proportions.csv
#        core=ref_Hs_SAT_01-1_scvi_LSshift_SN
#        tail=Hs_SAT_01-1_scvi_LSshift_SN
#        donor='Hs', transform='SAT_01-1_scvi_LSshift_SN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_02-1_degIntAllSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_02-1_degIntAllSN
#        tail=Hs_SAT_02-1_degIntAllSN
#        donor='Hs', transform='SAT_02-1_degIntAllSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_02-1_degIntSN_SCDC_proportions.csv
#        core=ref_Hs_SAT
N_SCDC_proportions.csv
#        core=ref_Hs_SAT_12-1_degSN
#        tail=Hs_SAT_12-1_degSN
#        donor='Hs', transform='SAT_12-1_degSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_12-1_degScviLSshift_SN_SCDC_proportions.csv
#        core=ref_Hs_SAT_12-1_degScviLSshift_SN
#        tail=Hs_SAT_12-1_degScviLSshift_SN
#        donor='Hs', transform='SAT_12-1_degScviLSshift_SN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_12-1_degScviSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_12-1_degScviSN
#        tail=Hs_SAT_12-1_degScviSN
#        donor='Hs', transform='SAT_12-1_degScviSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_12-1_pcaSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_12-1_pcaSN
#        tail=Hs_SAT_12-1_pcaSN
#        donor='Hs', transform='SAT_12-1_pcaSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_12-1_rawSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_12-1_rawSN
#        tail=Hs_SAT_12-1_rawSN
#        donor='Hs', transform='SAT_12-1_rawSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_12-1_scviSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_12-1_scviSN
#        tail=Hs_SAT_12-1_scviSN
#        donor='Hs', transform='SAT_12-1_scviSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_12-1_scvi_LSshift_SN_SCDC_proportions.csv
#        core=ref_Hs_SAT_12-1_scvi_LSshift_SN
#        tail=Hs_SAT_12-1_scvi_LSshift_SN
#        donor='Hs', transform='SAT_12-1_scvi_LSshift_SN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_13-1_degIntAllSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_13-1_degIntAllSN
#        tail=Hs_SAT_13-1_degIntAllSN
#        donor='Hs', transform='SAT_13-1_degIntAllSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_13-1_degIntSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_13-1_degIntSN
#        tail=Hs_SAT_13-1_degIntSN
#        donor='Hs', transform='SAT_13-1_degIntSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_13-1_degOtherSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_13-1_degOtherSN
#        tail=Hs_SAT_13-1_degOtherSN
#        donor='Hs', transform='SAT_13-1_degOtherSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_13-1_degPCA_SN_SCDC_proportions.csv
#        core=ref_Hs_SAT_13-1_degPCA_SN
#        tail=Hs_SAT_13-1_degPCA_SN
#        donor='Hs', transform='SAT_13-1_degPCA_SN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_13-1_degRandSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_13-1_degRandSN
#        tail=Hs_SAT_13-1_degRandSN
#        donor='Hs', transform='SAT_13-1_degRandSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_13-1_degSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_13-1_degSN
#        tail=Hs_SAT_13-1_degSN
#        donor='Hs', transform='SAT_13-1_degSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_13-1_degScviLSshift_SN_SCDC_proportions.csv
#        core=ref_Hs_SAT_13-1_degScviLSshift_SN
#        tail=Hs_SAT_13-1_degScviLSshift_SN
#        donor='Hs', transform='SAT_13-1_degScviLSshift_SN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_13-1_degScviSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_13-1_degScviSN
#        tail=Hs_SAT_13-1_degScviSN
#        donor='Hs', transform='SAT_13-1_degScviSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_13-1_pcaSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_13-1_pcaSN
#        tail=Hs_SAT_13-1_pcaSN
#        donor='Hs', transform='SAT_13-1_pcaSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_13-1_rawSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_13-1_rawSN
#        tail=Hs_SAT_13-1_rawSN
#        donor='Hs', transform='SAT_13-1_rawSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_13-1_scviSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_13-1_scviSN
#        tail=Hs_SAT_13-1_scviSN
#        donor='Hs', transform='SAT_13-1_scviSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_13-1_scvi_LSshift_SN_SCDC_proportions.csv
#        core=ref_Hs_SAT_13-1_scvi_LSshift_SN
#        tail=Hs_SAT_13-1_scvi_LSshift_SN
#        donor='Hs', transform='SAT_13-1_scvi_LSshift_SN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_253-1_degIntAllSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_253-1_degIntAllSN
#        tail=Hs_SAT_253-1_degIntAllSN
#        donor='Hs', transform='SAT_253-1_degIntAllSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_253-1_degIntSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_253-1_degIntSN
#        tail=Hs_SAT_253-1_degIntSN
#        donor='Hs', transform='SAT_253-1_degIntSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_253-1_degOtherSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_253-1_degOtherSN
#        tail=Hs_SAT_253-1_degOtherSN
#        donor='Hs', transform='SAT_253-1_degOtherSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_253-1_degPCA_SN_SCDC_proportions.csv
#        core=ref_Hs_SAT_253-1_degPCA_SN
#        tail=Hs_SAT_253-1_degPCA_SN
#        donor='Hs', transform='SAT_253-1_degPCA_SN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_253-1_degRandSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_253-1_degRandSN
#        tail=Hs_SAT_253-1_degRandSN
#        donor='Hs', transform='SAT_253-1_degRandSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_253-1_degSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_253-1_degSN
#        tail=Hs_SAT_253-1_degSN
#        donor='Hs', transform='SAT_253-1_degSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_253-1_degScviLSshift_SN_SCDC_proportions.csv
#        core=ref_Hs_SAT_253-1_degScviLSshift_SN
#        tail=Hs_SAT_253-1_degScviLSshift_SN
#        donor='Hs', transform='SAT_253-1_degScviLSshift_SN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_253-1_degScviSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_253-1_degScviSN
#        tail=Hs_SAT_253-1_degScviSN
#        donor='Hs', transform='SAT_253-1_degScviSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_253-1_pcaSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_253-1_pcaSN
#        tail=Hs_SAT_253-1_pcaSN
#        donor='Hs', transform='SAT_253-1_pcaSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_253-1_rawSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_253-1_rawSN
#        tail=Hs_SAT_253-1_rawSN
#        donor='Hs', transform='SAT_253-1_rawSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_253-1_scviSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_253-1_scviSN
#        tail=Hs_SAT_253-1_scviSN
#        donor='Hs', transform='SAT_253-1_scviSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_253-1_scvi_LSshift_SN_SCDC_proportions.csv
#        core=ref_Hs_SAT_253-1_scvi_LSshift_SN
#        tail=Hs_SAT_253-1_scvi_LSshift_SN
#        donor='Hs', transform='SAT_253-1_scvi_LSshift_SN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_255-1_degIntAllSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_255-1_degIntAllSN
#        tail=Hs_SAT_255-1_degIntAllSN
#        donor='Hs', transform='SAT_255-1_degIntAllSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_255-1_degIntSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_255-1_degIntSN
#        tail=Hs_SAT_255-1_degIntSN
#        donor='Hs', transform='SAT_255-1_degIntSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_255-1_degOtherSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_255-1_degOtherSN
#        tail=Hs_SAT_255-1_degOtherSN
#        donor='Hs', transform='SAT_255-1_degOtherSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_255-1_degPCA_SN_SCDC_proportions.csv
#        core=ref_Hs_SAT_255-1_degPCA_SN
#        tail=Hs_SAT_255-1_degPCA_SN
#        donor='Hs', transform='SAT_255-1_degPCA_SN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_255-1_degRandSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_255-1_degRandSN
#        tail=Hs_SAT_255-1_degRandSN
#        donor='Hs', transform='SAT_255-1_degRandSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_255-1_degSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_255-1_degSN
#        tail=Hs_SAT_255-1_degSN
#        donor='Hs', transform='SAT_255-1_degSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_255-1_degScviLSshift_SN_SCDC_proportions.csv
#        core=ref_Hs_SAT_255-1_degScviLSshift_SN
#        tail=Hs_SAT_255-1_degScviLSshift_SN
#        donor='Hs', transform='SAT_255-1_degScviLSshift_SN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_255-1_degScviSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_255-1_degScviSN
#        tail=Hs_SAT_255-1_degScviSN
#        donor='Hs', transform='SAT_255-1_degScviSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_255-1_pcaSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_255-1_pcaSN
#        tail=Hs_SAT_255-1_pcaSN
#        donor='Hs', transform='SAT_255-1_pcaSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_255-1_rawSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_255-1_rawSN
#        tail=Hs_SAT_255-1_rawSN
#        donor='Hs', transform='SAT_255-1_rawSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_255-1_scviSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_255-1_scviSN
#        tail=Hs_SAT_255-1_scviSN
#        donor='Hs', transform='SAT_255-1_scviSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_255-1_scvi_LSshift_SN_SCDC_proportions.csv
#        core=ref_Hs_SAT_255-1_scvi_LSshift_SN
#        tail=Hs_SAT_255-1_scvi_LSshift_SN
#        donor='Hs', transform='SAT_255-1_scvi_LSshift_SN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_256-1_degIntAllSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_256-1_degIntAllSN
#        tail=Hs_SAT_256-1_degIntAllSN
#        donor='Hs', transform='SAT_256-1_degIntAllSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_256-1_degIntSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_256-1_degIntSN
#        tail=Hs_SAT_256-1_degIntSN
#        donor='Hs', transform='SAT_256-1_degIntSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_256-1_degOtherSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_256-1_degOtherSN
#        tail=Hs_SAT_256-1_degOtherSN
#        donor='Hs', transform='SAT_256-1_degOtherSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_256-1_degPCA_SN_SCDC_proportions.csv
#        core=ref_Hs_SAT_256-1_degPCA_SN
#        tail=Hs_SAT_256-1_degPCA_SN
#        donor='Hs', transform='SAT_256-1_degPCA_SN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_256-1_degRandSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_256-1_degRandSN
#        tail=Hs_SAT_256-1_degRandSN
#        donor='Hs', transform='SAT_256-1_degRandSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_256-1_degSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_256-1_degSN
#        tail=Hs_SAT_256-1_degSN
#        donor='Hs', transform='SAT_256-1_degSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_256-1_degScviLSshift_SN_SCDC_proportions.csv
#        core=ref_Hs_SAT_256-1_degScviLSshift_SN
#        tail=Hs_SAT_256-1_degScviLSshift_SN
#        donor='Hs', transform='SAT_256-1_degScviLSshift_SN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_256-1_degScviSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_256-1_degScviSN
#        tail=Hs_SAT_256-1_degScviSN
#        donor='Hs', transform='SAT_256-1_degScviSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_256-1_pcaSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_256-1_pcaSN
#        tail=Hs_SAT_256-1_pcaSN
#        donor='Hs', transform='SAT_256-1_pcaSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_256-1_rawSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_256-1_rawSN
#        tail=Hs_SAT_256-1_rawSN
#        donor='Hs', transform='SAT_256-1_rawSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_256-1_scviSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_256-1_scviSN
#        tail=Hs_SAT_256-1_scviSN
#        donor='Hs', transform='SAT_256-1_scviSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_256-1_scvi_LSshift_SN_SCDC_proportions.csv
#        core=ref_Hs_SAT_256-1_scvi_LSshift_SN
#        tail=Hs_SAT_256-1_scvi_LSshift_SN
#        donor='Hs', transform='SAT_256-1_scvi_LSshift_SN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_266-1_degIntAllSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_266-1_degIntAllSN
#        tail=Hs_SAT_266-1_degIntAllSN
#        donor='Hs', transform='SAT_266-1_degIntAllSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_266-1_degIntSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_266-1_degIntSN
#        tail=Hs_SAT_266-1_degIntSN
#        donor='Hs', transform='SAT_266-1_degIntSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_266-1_degOtherSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_266-1_degOtherSN
#        tail=Hs_SAT_266-1_degOtherSN
#        donor='Hs', transform='SAT_266-1_degOtherSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_266-1_degPCA_SN_SCDC_proportions.csv
#        core=ref_Hs_SAT_266-1_degPCA_SN
#        tail=Hs_SAT_266-1_degPCA_SN
#        donor='Hs', transform='SAT_266-1_degPCA_SN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_266-1_degRandSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_266-1_degRandSN
#        tail=Hs_SAT_266-1_degRandSN
#        donor='Hs', transform='SAT_266-1_degRandSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_266-1_degSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_266-1_degSN
#        tail=Hs_SAT_266-1_degSN
#        donor='Hs', transform='SAT_266-1_degSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_266-1_degScviLSshift_SN_SCDC_proportions.csv
#        core=ref_Hs_SAT_266-1_degScviLSshift_SN
#        tail=Hs_SAT_266-1_degScviLSshift_SN
#        donor='Hs', transform='SAT_266-1_degScviLSshift_SN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_266-1_degScviSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_266-1_degScviSN
#        tail=Hs_SAT_266-1_degScviSN
#        donor='Hs', transform='SAT_266-1_degScviSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_266-1_pcaSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_266-1_pcaSN
#        tail=Hs_SAT_266-1_pcaSN
#        donor='Hs', transform='SAT_266-1_pcaSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_266-1_rawSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_266-1_rawSN
#        tail=Hs_SAT_266-1_rawSN
#        donor='Hs', transform='SAT_266-1_rawSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_266-1_scviSN_SCDC_proportions.csv
#        core=ref_Hs_SAT_266-1_scviSN
#        tail=Hs_SAT_266-1_scviSN
#        donor='Hs', transform='SAT_266-1_scviSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_Hs_SAT_266-1_scvi_LSshift_SN_SCDC_proportions.csv
#        core=ref_Hs_SAT_266-1_scvi_LSshift_SN
#        tail=Hs_SAT_266-1_scvi_LSshift_SN
#        donor='Hs', transform='SAT_266-1_scvi_LSshift_SN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_real_degIntAllSN_SCDC_proportions.csv
#        core=ref_real_degIntAllSN
#        tail=real_degIntAllSN
#        donor='real', transform='degIntAllSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_real_degIntSN_SCDC_proportions.csv
#        core=ref_real_degIntSN
#        tail=real_degIntSN
#        donor='real', transform='degIntSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_real_degOtherSN_SCDC_proportions.csv
#        core=ref_real_degOtherSN
#        tail=real_degOtherSN
#        donor='real', transform='degOtherSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_real_degRandSN_SCDC_proportions.csv
#        core=ref_real_degRandSN
#        tail=real_degRandSN
#        donor='real', transform='degRandSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_real_degSN_SCDC_proportions.csv
#        core=ref_real_degSN
#        tail=real_degSN
#        donor='real', transform='degSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_real_degScviLSshift_SN_SCDC_proportions.csv
#        core=ref_real_degScviLSshift_SN
#        tail=real_degScviLSshift_SN
#        donor='real', transform='degScviLSshift_SN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_real_degScviSN_SCDC_proportions.csv
#        core=ref_real_degScviSN
#        tail=real_degScviSN
#        donor='real', transform='degScviSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_real_degpcaSN_SCDC_proportions.csv
#        core=ref_real_degpcaSN
#        tail=real_degpcaSN
#        donor='real', transform='degpcaSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_real_pcaSN_SCDC_proportions.csv
#        core=ref_real_pcaSN
#        tail=real_pcaSN
#        donor='real', transform='pcaSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_real_rawSN_SCDC_proportions.csv
#        core=ref_real_rawSN
#        tail=real_rawSN
#        donor='real', transform='rawSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_real_scviSN_SCDC_proportions.csv
#        core=ref_real_scviSN
#        tail=real_scviSN
#        donor='real', transform='scviSN'
#        donor in donor_list? False
#
# DEBUG parse: fname=ref_real_scvi_LSshift_SN_SCDC_proportions.csv
#        core=ref_real_scvi_LSshift_SN
#        tail=real_scvi_LSshift_SN
#        donor='real', transform='scvi_LSshift_SN'
#        donor in donor_list? False
#
#
# === SUMMARY ===
# Accepted files (parsed successfully): 0
#
# Skipped files (unrecognised): 158
#   SKIP ref_Hs_SAT_01-1_degIntAllSN_SCDC_proportions.csv
#   SKIP ref_Hs_SAT_01-1_degIntSN_SCDC_proportions.csv
#   SKIP ref_Hs_SAT_01-1_degOtherSN_SCDC_proportions.csv
#   SKIP ref_Hs_SAT_01-1_degPCA_SN_SCDC_proportions.csv
#   SKIP ref_Hs_SAT_01-1_degRandSN_SCDC_proportions.csv
#   SKIP ref_Hs_SAT_01-1_degSN_SCDC_proportions.csv
#   SKIP ref_Hs_SAT_01-1_degScviLSshift_SN_SCDC_proportions.csv
#   SKIP ref_Hs_SAT_01-1_degScviSN_SCDC_proportions.csv
#   SKIP ref_Hs_SAT_01-1_pcaSN_SCDC_proportions.csv
#   SKIP ref_Hs_SAT_01-1_rawSN_SCDC_proportions.csv
