# %% [markdown]
# # Preprocessing data for Metastatic Breast Cancer Data (or Ovarian Cancer Data)

# %% [markdown]
# The following notebook is meant to be run through papermill parametrized for data type (res_name) of "MBC" (metastatic breast cancer) or "OVC" (ovarian cancer). It can aslo be run directly. Please download the data from the links below prior to running. The notebook QC the data, and saves it to be used later. The data is already filtered according to the original publication.

# %% [markdown]
# [Original paper data can be found here](https://www.nature.com/articles/s41591-020-0844-1#data-availability)
#
# [Data can be downaloded here](https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE140819)
#
# ### **We recommend downloading "custom", only the following samples:**
#
# ### MBC:
#
# #### Nuclei	HTAPP-963-SMP-4741:
#
# GSM4186979_HTAPP-963-SMP-4741_CST_channel2_raw_gene_bc_matrices_h5.h5.gz
#
# GSM4186979_metadata_HTAPP-963-SMP-4741_CST_channel2.csv.gz
#
# #### Cells HTAPP-963-SMP-4741 & HTAPP-285-SMP-751:
#
# GSM4186974_HTAPP-963-SMP-4741_fresh_channel1_raw_gene_bc_matrices_h5.h5.gz
#
# GSM4186974_metadata_HTAPP-963-SMP-4741_fresh_channel1.csv.gz
#
# GSM4186973_HTAPP-285-SMP-751_fresh_channel1_raw_gene_bc_matrices_h5.h5.gz
#
# GSM4186973_metadata_HTAPP-285-SMP-751_fresh_channel1.csv.gz

# %%
# import the dependencies
import sys
import sys
import numpy as np
import os
import pandas as pd
import scipy as sp
from scipy.sparse import coo_matrix
import collections
import scanpy as sc
import anndata as ad
import gzip
import re
import shutil
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pickle
from pathlib import Path

# Ensure PYTHONPATH includes the parent directory of 'src'
sys.path.insert(1, "../../")
sys.path.insert(1, "../")
sys.path.insert(1, "../../../../../")

from src.helpers import (
    match_cell_types,
    load_MBC_data,
    make_prop_table,
    assign_cell_types,
    load_OVC_data,
)

# %% [markdown]
# We'll demostrate with metastatic breast cancer data from:

# %%
res_name = "MBC"

# %%
# Parameters
res_name = "MBC"

# %% [markdown]
# ## Reading in the single-cell and single-nucleus data

# %% [markdown]
# Single-Cell

# %%
if res_name == "MBC":
    sc_adata, sc_metadata = load_MBC_data("single_cell")
elif res_name == "OVC":
    sc_adata, sc_metadata = load_OVC_data("single_cell")
sc_metadata
# Out:
# Extracting /projects/aivich@xsede.org/deconvolution_sc_sn_comparison/notebooks/../data/MBC/GSE140819_RAW.tar to /projects/aivich@xsede.org/deconvolution_sc_sn_comparison/notebooks/../data/MBC/...
# Extraction complete.
# /projects/aivich@xsede.org/.conda/envs/env_deconv/lib/python3.10/site-packages/anndata/_core/anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
#                                      Unnamed: 0          annotate  nReads  \
# 0     HTAPP-963-SMP-4741_fresh-AAACCTGAGACCTTTG            T cell    2544
# 1     HTAPP-963-SMP-4741_fresh-AAACCTGAGTACTTGC           NK cell    3185
# 2     HTAPP-963-SMP-4741_fresh-AAACCTGCAAGAGGCT   Epithelial cell   28067
# 3     HTAPP-963-SMP-4741_fresh-AAACCTGCAGTTAACC            T cell    5698
# 4     HTAPP-963-SMP-4741_fresh-AAACCTGCATCACGTA  Endothelial cell   11602
# ...                                         ...               ...     ...
# 5158  HTAPP-963-SMP-4741_fresh-TTTGTCACATGCAACT            T cell    5506
# 5159  HTAPP-963-SMP-4741_fresh-TTTGTCAGTACTTGAC        Fibroblast    4279
# 5160  HTAPP-963-SMP-4741_fresh-TTTGTCATCAGGCAAG            T cell    2364
# 5161  HTAPP-963-SMP-4741_fresh-TTTGTCATCGGTGTTA            B cell    3513
# 5162  HTAPP-963-SMP-4741_fresh-TTTGTCATCTCATTCA        Macrophage    3725
#
#        nUMI  nGene  percent_mito  emptydrop  doublet                cell
# 0      1098    603      0.063752      False    False  AAACCTGAGACCTTTG-1
# 1      1362    706      0.041850      False    False  AAACCTGAGTACTTGC-1
# 2     11621   2347      0.003012      False    False  AAACCTGCAAGAGGCT-1
# 3      2386   1004      0.021375      False    False  AAACCTGCAGTTAACC-1
# 4      5093   1985      0.036913      False    False  AAACCTGCATCACGTA-1
# ...     ...    ...           ...        ...      ...                 ...
# 5158   2354   1059      0.037383      False    False  TTTGTCACATGCAACT-1
# 5159   1811    943      0.023744      False    False  TTTGTCAGTACTTGAC-1
# 5160   1021    535      0.043095      False    False  TTTGTCATCAGGCAAG-1
# 5161   1555    591      0.054019      False    False  TTTGTCATCGGTGTTA-1
# 5162   1682    716      0.067776      False    False  TTTGTCATCTCATTCA-1
#
# [5163 rows x 9 columns]

# %% [markdown]
# Single-Nucleus:

# %%
if res_name == "MBC":
    sn_adata, sn_metadata = load_MBC_data("single_nucleus")
elif res_name == "OVC":
    sn_adata, sn_metadata = load_OVC_data("single_nucleus")
sn_metadata
# Out:
# Skipping extraction: Data already exists in /projects/aivich@xsede.org/deconvolution_sc_sn_comparison/notebooks/../data/MBC/.
# /projects/aivich@xsede.org/.conda/envs/env_deconv/lib/python3.10/site-packages/anndata/_core/anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
#                                             Unnamed: 0         annotate  \
# 0     HTAPP-963-SMP-4741_CST_channel2-AAACCTGAGAAACCTA       Macrophage
# 1     HTAPP-963-SMP-4741_CST_channel2-AAACCTGAGAGGGATA  Epithelial cell
# 2     HTAPP-963-SMP-4741_CST_channel2-AAACCTGAGAGTGACC           T cell
# 3     HTAPP-963-SMP-4741_CST_channel2-AAACCTGAGCAACGGT  Epithelial cell
# 4     HTAPP-963-SMP-4741_CST_channel2-AAACCTGAGCCACCTG  Epithelial cell
# ...                                                ...              ...
# 9852  HTAPP-963-SMP-4741_CST_channel2-TTTGTCATCGCAAACT       Hepatocyte
# 9853  HTAPP-963-SMP-4741_CST_channel2-TTTGTCATCGTGGTCG           T cell
# 9854  HTAPP-963-SMP-4741_CST_channel2-TTTGTCATCGTTACGA       Hepatocyte
# 9855  HTAPP-963-SMP-4741_CST_channel2-TTTGTCATCTGCTGTC  Epithelial cell
# 9856  HTAPP-963-SMP-4741_CST_channel2-TTTGTCATCTTTACAC       Macrophage
#
#       nReads   nUMI  nGene  percent_mito  doublet                cell
# 0       1352    572    486      0.012238    False  AAACCTGAGAAACCTA-1
# 1       3313   1477   1093      0.041300    False  AAACCTGAGAGGGATA-1
# 2       2950   1284   1053      0.011682    False  AAACCTGAGAGTGACC-1
# 3       5109   2211   1532      0.030755    False  AAACCTGAGCAACGGT-1
# 4       1033    476    372      0.130252    False  AAACCTGAGCCACCTG-1
# ...      ...    ...    ...           ...      ...                 ...
# 9852   23025  10378   5308      0.013201    False  TTTGTCATCGCAAACT-1
# 9853    6907   3220   2261      0.016770    False  TTTGTCATCGTGGTCG-1
# 9854    3595   1680   1233      0.009524    False  TTTGTCATCGTTACGA-1
# 9855   10389   4844   2844      0.011767    False  TTTGTCATCTGCTGTC-1
# 9856    1801    885    713      0.016949    False  TTTGTCATCTTTACAC-1
#
# [9857 rows x 8 columns]

# %% [markdown]
# And testing Single-cell:

# %%
if res_name == "MBC":
    sc_adata_test, sc_metadata_test = load_MBC_data("single_cell", load_testing=True)
elif res_name == "OVC":
    sc_adata_test, sc_metadata_test = load_OVC_data("single_cell", load_testing=True)
sc_metadata_test
# Out:
# Skipping extraction: Data already exists in /projects/aivich@xsede.org/deconvolution_sc_sn_comparison/notebooks/../data/MBC/.
# /projects/aivich@xsede.org/.conda/envs/env_deconv/lib/python3.10/site-packages/anndata/_core/anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
#                                              Unnamed: 0          annotate  \
# 0     HTAPP-285-SMP-751_fresh_channel1-AAACCTGAGAGTGACC   Epithelial cell
# 1     HTAPP-285-SMP-751_fresh_channel1-AAACCTGAGCAAATCA   Epithelial cell
# 2     HTAPP-285-SMP-751_fresh_channel1-AAACCTGGTACGCACC   Epithelial cell
# 3     HTAPP-285-SMP-751_fresh_channel1-AAACCTGGTCGAGATG   Epithelial cell
# 4     HTAPP-285-SMP-751_fresh_channel1-AAACCTGTCCCAAGAT            T cell
# ...                                                 ...               ...
# 4458  HTAPP-285-SMP-751_fresh_channel1-TTTGTCAGTACCGAGA   Epithelial cell
# 4459  HTAPP-285-SMP-751_fresh_channel1-TTTGTCAGTCAGCTAT   Epithelial cell
# 4460  HTAPP-285-SMP-751_fresh_channel1-TTTGTCAGTCTAGCGC  Endothelial cell
# 4461  HTAPP-285-SMP-751_fresh_channel1-TTTGTCATCAGTTTGG        Macrophage
# 4462  HTAPP-285-SMP-751_fresh_channel1-TTTGTCATCGTGGACC   Epithelial cell
#
#       nReads   nUMI  nGene  percent_mito  emptydrop  doublet  \
# 0      28587  14260   3215      0.021388      False    False
# 1      70728  36824   5838      0.070633      False    False
# 2      44899  23309   4620      0.065425      False    False
# 3      28103  14936   3753      0.105182      False    False
# 4       7402   3768   1341      0.021497      False    False
# ...      ...    ...    ...           ...        ...      ...
# 4458   21192  11213   3164      0.050299      False    False
# 4459   53299  27905   4721      0.054793      False    False
# 4460    2947   1509    697      0.001325      False    False
# 4461   16329   8690   2144      0.024856      False    False
# 4462   34406  18398   3868      0.096913      False    False
#
#                     cell
# 0     AAACCTGAGAGTGACC-1
# 1     AAACCTGAGCAAATCA-1
# 2     AAACCTGGTACGCACC-1
# 3     AAACCTGGTCGAGATG-1
# 4     AAACCTGTCCCAAGAT-1
# ...                  ...
# 4458  TTTGTCAGTACCGAGA-1
# 4459  TTTGTCAGTCAGCTAT-1
# 4460  TTTGTCAGTCTAGCGC-1
# 4461  TTTGTCATCAGTTTGG-1
# 4462  TTTGTCATCGTGGACC-1
#
# [4463 rows x 9 columns]

# %%
# QC, making sure our cells are the same in metadata and count matrix
idx_keep = np.intersect1d(sn_metadata.cell.values, sn_adata.obs.index.values)
sn_adata = sn_adata[idx_keep, :]

idx_keep = np.intersect1d(sc_metadata.cell.values, sc_adata.obs.index.values)
sc_adata = sc_adata[idx_keep, :]

idx_keep = np.intersect1d(sc_metadata_test.cell.values, sc_adata_test.obs.index.values)
sc_adata_test = sc_adata_test[idx_keep, :]

# %% [markdown]
# Assigning information from data:
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE140819

# %%
# data type
sn_adata.obs["data_type"] = "single_nucleus"
sc_adata.obs["data_type"] = "single_cell"
sc_adata_test.obs["data_type"] = "single_cell"
# Out:
# /projects/aivich@xsede.org/code-server/tmp/ipykernel_900733/43901299.py:2: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   sn_adata.obs["data_type"] = "single_nucleus"
# /projects/aivich@xsede.org/code-server/tmp/ipykernel_900733/43901299.py:3: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   sc_adata.obs["data_type"] = "single_cell"
# /projects/aivich@xsede.org/code-server/tmp/ipykernel_900733/43901299.py:4: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   sc_adata_test.obs["data_type"] = "single_cell"

# %% [markdown]
# ## QC

# %% [markdown]
# QC of count matrix, rouhghly based on:
#
# Scanpy https://scanpy-tutorials.readthedocs.io/en/latest/pbmc3k.html

# %%
sc.pl.highest_expr_genes(
    sn_adata,
    n_top=20,
)
sc.pl.highest_expr_genes(
    sc_adata,
    n_top=20,
)
sc.pl.highest_expr_genes(
    sc_adata_test,
    n_top=20,
)

# %%
# QC, check it is not normalized
print(sn_adata.X.max())
print(sc_adata.X.max())
print(sc_adata_test.X.max())
# Out:
# 1214.0
# 8788.0
# 8351.0

# %% [markdown]
# We'll remove genes with high mitochondrial content

# %%
#  checking mitochondrial content, should not exceed 20%
sn_adata.var["mt"] = sn_adata.var_names.str.startswith(
    "MT-"
)  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(
    sn_adata, qc_vars=["mt"], percent_top=None, log1p=False, inplace=True
)
sc.pl.violin(
    sn_adata,
    ["n_genes_by_counts", "total_counts", "pct_counts_mt"],
    jitter=0.4,
    multi_panel=True,
)

# remove genes with high mitochondrial content
sc_adata.var["mt"] = sc_adata.var_names.str.startswith(
    "MT-"
)  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(
    sc_adata, qc_vars=["mt"], percent_top=None, log1p=False, inplace=True
)
sc.pl.violin(
    sc_adata,
    ["n_genes_by_counts", "total_counts", "pct_counts_mt"],
    jitter=0.4,
    multi_panel=True,
)

# remove genes with high mitochondrial content
sc_adata_test.var["mt"] = sc_adata_test.var_names.str.startswith(
    "MT-"
)  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(
    sc_adata_test, qc_vars=["mt"], percent_top=None, log1p=False, inplace=True
)
sc.pl.violin(
    sc_adata_test,
    ["n_genes_by_counts", "total_counts", "pct_counts_mt"],
    jitter=0.4,
    multi_panel=True,
)

# %%
sc.pl.scatter(sn_adata, x="total_counts", y="pct_counts_mt")
sc.pl.scatter(sn_adata, x="total_counts", y="n_genes_by_counts")

sc.pl.scatter(sc_adata, x="total_counts", y="pct_counts_mt")
sc.pl.scatter(sc_adata, x="total_counts", y="n_genes_by_counts")

sc.pl.scatter(sc_adata_test, x="total_counts", y="pct_counts_mt")
sc.pl.scatter(sc_adata_test, x="total_counts", y="n_genes_by_counts")

# %% [markdown]
# ## **Assigning cell types:**

# %%
sn_adata = assign_cell_types(sn_adata, sn_metadata["annotate"].values)
sc_adata = assign_cell_types(sc_adata, sc_metadata["annotate"].values)
sc_adata_test = assign_cell_types(sc_adata_test, sc_metadata_test["annotate"].values)
# Out:
# Done!
# Cell Types in Data are: cell_types
# Epithelial cell     6964
# Macrophage          1153
# T cell               782
# Hepatocyte           437
# Endothelial cell     387
# Fibroblast           121
# B cell                13
# Name: count, dtype: int64
# Done!
# Cell Types in Data are: cell_types
# T cell              2571
# Macrophage           778
# NK cell              725
# Epithelial cell      605
# Endothelial cell     231
# B cell               124
# Hepatocyte            72
# Fibroblast            57
# Name: count, dtype: int64
# Done!
# Cell Types in Data are: cell_types
# Epithelial cell     3143
# T cell               562
# NK cell              233
# Macrophage           223
# Endothelial cell     163
# Hepatocyte            50
# Fibroblast            47
# B cell                42
# Name: count, dtype: int64

# %%
# making copy to keep unnormalized for export
sn_adata_copy = sn_adata.copy()
sc_adata_copy = sc_adata.copy()
sc_adata_test_copy = sc_adata_test.copy()

# normalize to 10K counts per cell
sc.pp.normalize_total(sn_adata, target_sum=1e4)
# logging local adata
sc.pp.log1p(sn_adata)

sc.pp.normalize_total(sc_adata, target_sum=1e4)
# logging local adata
sc.pp.log1p(sc_adata)

sc.pp.normalize_total(sc_adata_test, target_sum=1e4)
# logging local adata
sc.pp.log1p(sc_adata_test)

# %%
highly_var_genes = sc.pp.highly_variable_genes(
    sn_adata, min_mean=0.0125, max_mean=3, min_disp=0.5
)
sc.pl.highly_variable_genes(sn_adata)

highly_var_genes = sc.pp.highly_variable_genes(
    sc_adata, min_mean=0.0125, max_mean=3, min_disp=0.5
)
sc.pl.highly_variable_genes(sc_adata)

highly_var_genes = sc.pp.highly_variable_genes(
    sc_adata_test, min_mean=0.0125, max_mean=3, min_disp=0.5
)
sc.pl.highly_variable_genes(sc_adata_test)

# %%
# calculate neighborhood graph
sc.pp.neighbors(sn_adata)

# make umap
sc.tl.umap(sn_adata)

# plot some markers of the RAW data
sc.pl.umap(sn_adata, color="cell_types", legend_fontsize=8)
# Out:
# /projects/aivich@xsede.org/.conda/envs/env_deconv/lib/python3.10/site-packages/scanpy/tools/_utils.py:41: UserWarning: You’re trying to run this on 33694 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
#   warnings.warn(

# %%
# calculate neighborhood graph
sc.pp.neighbors(sc_adata)

# make umap
sc.tl.umap(sc_adata)

# plot some markers of the RAW data
sc.pl.umap(sc_adata, color="cell_types", legend_fontsize=8)
# Out:
# /projects/aivich@xsede.org/.conda/envs/env_deconv/lib/python3.10/site-packages/scanpy/tools/_utils.py:41: UserWarning: You’re trying to run this on 32738 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
#   warnings.warn(

# %%
# calculate neighborhood graph
sc.pp.neighbors(sc_adata_test)

# make umap
sc.tl.umap(sc_adata_test)

# plot some markers of the RAW data
sc.pl.umap(sc_adata_test, color="cell_types", legend_fontsize=8)
# Out:
# /projects/aivich@xsede.org/.conda/envs/env_deconv/lib/python3.10/site-packages/scanpy/tools/_utils.py:41: UserWarning: You’re trying to run this on 33694 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
#   warnings.warn(

# %% [markdown]
# ## Cell type assignment QC:

# %%
# and repeat for unnormalized data
sn_adata_copy.obs["cell_types"] = sn_adata.obs["cell_types"]
sc_adata_copy.obs["cell_types"] = sc_adata.obs["cell_types"]
sc_adata_test_copy.obs["cell_types"] = sc_adata_test.obs["cell_types"]

# %%
sn_prop = make_prop_table(sn_adata, "cell_types")
sn_prop = sn_prop[:-1]
sn_prop.sort_values("Cell_Types")
# Out:
#          Cell_Types  Num_Cells  Prop_Cells
# 6            B cell         13    0.001319
# 3  Endothelial cell        387    0.039261
# 1   Epithelial cell       6964    0.706503
# 4        Fibroblast        121    0.012276
# 5        Hepatocyte        437    0.044334
# 0        Macrophage       1153    0.116973
# 2            T cell        782    0.079334

# %%
sc_prop = make_prop_table(sc_adata, "cell_types")
sc_prop = sc_prop[:-1]
sc_prop.sort_values("Cell_Types")
# Out:
#          Cell_Types  Num_Cells  Prop_Cells
# 6            B cell        124    0.024017
# 3  Endothelial cell        231    0.044741
# 2   Epithelial cell        605    0.117180
# 7        Fibroblast         57    0.011040
# 4        Hepatocyte         72    0.013945
# 5        Macrophage        778    0.150688
# 1           NK cell        725    0.140422
# 0            T cell       2571    0.497966

# %%
sc_prop_test = make_prop_table(sc_adata_test, "cell_types")
sc_prop_test = sc_prop_test[:-1]
sc_prop_test.sort_values("Cell_Types")
# Out:
#          Cell_Types  Num_Cells  Prop_Cells
# 7            B cell         42    0.009411
# 3  Endothelial cell        163    0.036523
# 0   Epithelial cell       3143    0.704235
# 6        Fibroblast         47    0.010531
# 5        Hepatocyte         50    0.011203
# 4        Macrophage        223    0.049966
# 2           NK cell        233    0.052207
# 1            T cell        562    0.125924

# %% [markdown]
# ## Now matching cell types in both

# %%
sn_adata, sc_adata = match_cell_types(
    sn_adata_copy,
    sc_adata_copy,
    np.intersect1d(sn_adata.obs.cell_types.unique(), sc_adata.obs.cell_types.unique()),
)

# %%
sc_adata_test, sc_adata = match_cell_types(
    sc_adata_test_copy,
    sc_adata_copy,
    np.intersect1d(
        sc_adata_test.obs.cell_types.unique(), sc_adata.obs.cell_types.unique()
    ),
)

# %%
# QC:
print("Cells in single-nucleus:")
print(sn_adata.obs.cell_types.unique())
print("Cells in single-cell:")
print(sc_adata.obs.cell_types.unique())
print("Cells in single-cell testing set:")
print(sc_adata_test.obs.cell_types.unique())
# Out:
# Cells in single-nucleus:
# ['Macrophage', 'Epithelial cell', 'T cell', 'Endothelial cell', 'Fibroblast', 'Hepatocyte', 'B cell']
# Categories (7, object): ['B cell', 'Endothelial cell', 'Epithelial cell', 'Fibroblast', 'Hepatocyte', 'Macrophage', 'T cell']
# Cells in single-cell:
# ['T cell', 'Epithelial cell', 'Endothelial cell', 'Hepatocyte', 'Macrophage', 'B cell', 'Fibroblast']
# Categories (7, object): ['B cell', 'Endothelial cell', 'Epithelial cell', 'Fibroblast', 'Hepatocyte', 'Macrophage', 'T cell']
# Cells in single-cell testing set:
# ['Epithelial cell', 'T cell', 'Endothelial cell', 'Macrophage', 'Hepatocyte', 'Fibroblast', 'B cell']
# Categories (7, object): ['B cell', 'Endothelial cell', 'Epithelial cell', 'Fibroblast', 'Hepatocyte', 'Macrophage', 'T cell']

# %% [markdown]
# ## Saving both

# %%
# These should not be normalized
print(sn_adata.X.max())
print(sc_adata.X.max())
print(sc_adata_test.X.max())
# Out:
# 1214.0
# 8788.0
# 8351.0

# %% [markdown]
# ## Finally matching genes

# %%
genes_to_keep = sorted(set(sn_adata.var_names.values)&set(sc_adata.var_names.values)&set(sc_adata_test.var_names.values))
genes_to_keep
# Out:
# ['A1BG',
#  'A1BG-AS1',
#  'A1CF',
#  'A2M',
#  'A2M-AS1',
#  'A2ML1',
#  'A2ML1-AS1',
#  'A2ML1-AS2',
#  'A3GALT2',
#  'A4GALT',
#  'A4GNT',
#  'AAAS',
#  'AACS',
#  'AADAC',
#  'AADACL2',
#  'AADACL3',
#  'AADACL4',
#  'AADAT',
#  'AAED1',
#  'AAGAB',
#  'AAK1',
#  'AAMDC',
#  'AAMP',
#  'AANAT',
#  'AAR2',
#  'AARD',
#  'AARS',
#  'AARS2',
#  'AARSD1',
#  'AASDH',
#  'AASDHPPT',
#  'AASS',
#  'AATF',
#  'AATK',
#  'AATK-AS1',
#  'AB019440.50',
#  'ABAT',
#  'ABCA1',
#  'ABCA10',
#  'ABCA12',
#  'ABCA13',
#  'ABCA2',
#  'ABCA3',
#  'ABCA4',
#  'ABCA5',
#  'ABCA6',
#  'ABCA7',
#  'ABCA8',
#  'ABCA9',
#  'ABCA9-AS1',
#  'ABCB1',
#  'ABCB10',
#  'ABCB11',
#  'ABCB4',
#  'ABCB5',
#  'ABCB6',
#  'ABCB7',
#  'ABCB8',
#  'ABCB9',
#  'ABCC1',
#  'ABCC10',
#  'ABCC11',
#  'ABCC12',
#  'ABCC2',
#  'ABCC3',
#  'ABCC4',
#  'ABCC5',
#  'ABCC5-AS1',
#  'ABCC6',
#  'ABCC8',
#  'ABCC9',
#  'ABCD1',
#  'ABCD2',
#  'ABCD3',
#  'ABCD4',
#  'ABCE1',
#  'ABCF1',
#  'ABCF2',
#  'ABCF3',
#  'ABCG1',
#  'ABCG2',
#  'ABCG4',
#  'ABCG5',
#  'ABCG8',
#  'ABHD1',
#  'ABHD10',
#  'ABHD11',
#  'ABHD12',
#  'ABHD12B',
#  'ABHD13',
#  'ABHD14A',
#  'ABHD14A-ACY1',
#  'ABHD14B',
#  'ABHD15',
#  'ABHD16A',
#  'ABHD16B',
#  'ABHD17A',
#  'ABHD17B',
#  'ABHD17C',
#  'ABHD2',
#  'ABHD3',
#  'ABHD4',
#  'ABHD5',
#  'ABHD6',
#  'ABHD8',
#  'ABI1',
#  'ABI2',
#  'ABI3',
#  'ABI3BP',
#  'ABL1',
#  'ABL2',
#  'ABLIM1',
#  'ABLIM2',
#  'ABLIM3',
#  'ABR',
#  'ABRA',
#  'ABRACL',
#  'ABT1',
#  'ABTB1',
#  'ABTB2',
#  'AC000032.2',
#  'AC000036.4',
#  'AC000067.1',
#  'AC000068.10',
#  'AC000068.5',
#  'AC000068.9',
#  'AC000099.1',
#  'AC000111.3',
#  'AC000111.6',
#  'AC000123.4',
#  'AC000124.1',
#  'AC000370.2',
#  'AC002056.5',
#  'AC002064.4',
#  'AC002064.5',
#  'AC002066.1',
#  'AC002076.10',
#  'AC002115.5',
#  'AC002115.9',
#  'AC002116.7',
#  'AC002117.1',
#  'AC002127.4',
#  'AC002128.5',
#  'AC002306.1',
#  'AC002310.12',
#  'AC002310.13',
#  'AC002310.7',
#  'AC002331.1',
#  'AC002368.4',
#  'AC002383.2',
#  'AC002386.1',
#  'AC002398.11',
#  'AC002398.12',
#  'AC002398.13',
#  'AC002398.9',
#  'AC002401.1',
#  'AC002429.5',
#  'AC002451.3',
#  'AC002454.1',
#  'AC002456.2',
#  'AC002463.3',
#  'AC002465.2',
#  'AC002467.7',
#  'AC002472.11',
#  'AC002480.2',
#  'AC002480.3',
#  'AC002480.4',
#  'AC002511.2',
#  'AC002511.3',
#  'AC002539.1',
#  'AC002550.5',
#  'AC002985.3',
#  'AC003002.4',
#  'AC003002.6',
#  'AC003005.2',
#  'AC003005.4',
#  'AC003006.7',
#  'AC003009.1',
#  'AC003075.4',
#  'AC003084.2',
#  'AC003088.1',
#  'AC003090.1',
#  'AC003092.1',
#  'AC003092.2',
#  'AC003101.1',
#  'AC003664.1',
#  'AC003682.16',
#  'AC003956.1',
#  'AC003958.2',
#  'AC003973.4',
#  'AC003973.5',
#  'AC003984.1',
#  'AC003985.1',
#  'AC003986.5',
#  'AC003986.6',
#  'AC003986.7',
#  'AC003988.1',
#  'AC003991.3',
#  'AC004009.3',
#  'AC004012.1',
#  'AC004014.3',
#  'AC004019.13',
#  'AC004051.2',
#  'AC004053.1',
#  'AC004054.1',
#  'AC004063.1',
#  'AC004066.3',
#  'AC004067.5',
#  'AC004069.2',
#  'AC004070.1',
#  'AC004076.7',
#  'AC004076.9',
#  'AC004112.4',
#  'AC004125.3',
#  'AC004156.3',
#  'AC004158.3',
#  'AC004160.4',
#  'AC004221.2',
#  'AC004231.2',
#  'AC004237.1',
#  'AC004257.1',
#  'AC004381.6',
#  'AC004381.7',
#  'AC004448.2',
#  'AC004448.5',
#  'AC004449.6',
#  'AC004471.10',
#  'AC004471.9',
#  'AC004485.3',
#  'AC004490.1',
#  'AC004510.3',
#  'AC004535.2',
#  'AC004540.4',
#  'AC004540.5',
#  'AC004543.2',
#  'AC004549.6',
#  'AC004593.3',
#  'AC004603.4',
#  'AC004623.2',
#  'AC004637.1',
#  'AC004691.5',
#  'AC004692.4',
#  'AC004702.2',
#  'AC004744.3',
#  'AC004775.5',
#  'AC004824.2',
#  'AC004837.4',
#  'AC004837.5',
#  'AC004840.8',
#  'AC004854.4',
#  'AC004862.6',
#  'AC004869.2',
#  'AC004869.3',
#  'AC004870.3',
#  'AC004878.2',
#  'AC004878.8',
#  'AC004893.11',
#  'AC004895.4',
#  'AC004906.3',
#  'AC004920.3',
#  'AC004941.3',
#  'AC004947.2',
#  'AC004951.6',
#  'AC004988.1',
#  'AC005008.2',
#  'AC005009.1',
#  'AC005009.2',
#  'AC005013.5',
#  'AC005019.3',
#  'AC005037.3',
#  'AC005042.4',
#  'AC005042.5',
#  'AC005076.5',
#  'AC005082.12',
#  'AC005104.3',
#  'AC005150.1',
#  'AC005152.3',
#  'AC005162.4',
#  'AC005162.5',
#  'AC005197.2',
#  'AC005220.3',
#  'AC005224.2',
#  'AC005235.1',
#  'AC005237.4',
#  'AC005253.2',
#  'AC005253.4',
#  'AC005256.1',
#  'AC005262.2',
#  'AC005262.3',
#  'AC005264.2',
#  'AC005276.1',
#  'AC005281.1',
#  'AC005281.2',
#  'AC005301.8',
#  'AC005304.1',
#  'AC005307.1',
#  'AC005307.3',
#  'AC005324.6',
#  'AC005324.7',
#  'AC005329.7',
#  'AC005330.2',
#  'AC005339.2',
#  'AC005355.1',
#  'AC005355.2',
#  'AC005358.3',
#  'AC005387.2',
#  'AC005387.3',
#  'AC005391.2',
#  'AC005392.13',
#  'AC005394.1',
#  'AC005477.1',
#  'AC005481.5',
#  'AC005487.2',
#  'AC005498.3',
#  'AC005498.4',
#  'AC005522.7',
#  'AC005523.2',
#  'AC005523.3',
#  'AC005534.8',
#  'AC005538.5',
#  'AC005540.3',
#  'AC005546.2',
#  'AC005550.3',
#  'AC005550.5',
#  'AC005592.1',
#  'AC005592.2',
#  'AC005592.3',
#  'AC005597.1',
#  'AC005606.14',
#  'AC005606.15',
#  'AC005614.3',
#  'AC005616.1',
#  'AC005616.2',
#  'AC005618.6',
#  'AC005624.2',
#  'AC005625.1',
#  'AC005703.2',
#  'AC005703.3',
#  'AC005740.5',
#  'AC005740.6',
#  'AC005754.7',
#  'AC005754.8',
#  'AC005757.6',
#  'AC005757.7',
#  'AC005772.2',
#  'AC005775.2',
#  'AC005779.2',
#  'AC005780.1',
#  'AC005786.5',
#  'AC005786.7',
#  'AC005789.9',
#  'AC005808.3',
#  'AC005863.1',
#  'AC005863.2',
#  'AC005932.1',
#  'AC005944.2',
#  'AC005954.4',
#  'AC006000.5',
#  'AC006004.1',
#  'AC006007.1',
#  'AC006019.3',
#  'AC006019.4',
#  'AC006026.13',
#  'AC006037.2',
#  'AC006041.1',
#  'AC006042.6',
#  'AC006042.7',
#  'AC006076.1',
#  'AC006116.12',
#  'AC006116.17',
#  'AC006116.21',
#  'AC006126.3',
#  'AC006126.4',
#  'AC006129.1',
#  'AC006129.2',
#  'AC006130.3',
#  'AC006150.1',
#  'AC006159.4',
#  'AC006159.5',
#  'AC006160.5',
#  'AC006196.1',
#  'AC006227.1',
#  'AC006262.10',
#  'AC006262.4',
#  'AC006262.5',
#  'AC006272.1',
#  'AC006272.2',
#  'AC006273.4',
#  'AC006273.5',
#  'AC006277.2',
#  'AC006296.1',
#  'AC006296.2',
#  'AC006369.2',
#  'AC006369.3',
#  'AC006372.4',
#  'AC006372.5',
#  'AC006372.6',
#  'AC006373.1',
#  'AC006378.2',
#  'AC006380.3',
#  'AC006458.3',
#  'AC006460.2',
#  'AC006482.1',
#  'AC006486.9',
#  'AC006538.4',
#  'AC006547.13',
#  'AC006547.15',
#  'AC006547.8',
#  'AC006552.1',
#  'AC006942.4',
#  'AC006946.15',
#  'AC006946.16',
#  'AC006946.17',
#  'AC006960.7',
#  'AC006994.2',
#  'AC007009.1',
#  'AC007036.6',
#  'AC007038.7',
#  'AC007040.11',
#  'AC007040.6',
#  'AC007040.8',
#  'AC007050.17',
#  'AC007064.24',
#  'AC007078.4',
#  'AC007091.1',
#  'AC007098.1',
#  'AC007099.1',
#  'AC007099.2',
#  'AC007106.1',
#  'AC007126.1',
#  'AC007128.1',
#  'AC007131.1',
#  'AC007131.2',
#  'AC007161.5',
#  'AC007163.3',
#  'AC007163.6',
#  'AC007179.1',
#  'AC007182.6',
#  'AC007192.6',
#  'AC007193.10',
#  'AC007193.6',
#  'AC007193.8',
#  'AC007193.9',
#  'AC007204.2',
#  'AC007228.11',
#  'AC007228.5',
#  'AC007228.9',
#  'AC007246.3',
#  'AC007249.3',
#  'AC007250.4',
#  'AC007251.2',
#  'AC007255.8',
#  'AC007271.3',
#  'AC007277.3',
#  'AC007285.6',
#  'AC007285.7',
#  'AC007292.3',
#  'AC007292.4',
#  'AC007292.6',
#  'AC007292.7',
#  'AC007308.7',
#  'AC007317.1',
#  'AC007319.1',
#  'AC007327.5',
#  'AC007349.4',
#  'AC007349.5',
#  'AC007349.7',
#  'AC007359.6',
#  'AC007362.3',
#  'AC007364.1',
#  'AC007365.1',
#  'AC007365.3',
#  'AC007381.3',
#  'AC007383.3',
#  'AC007383.4',
#  'AC007386.2',
#  'AC007386.4',
#  'AC007389.3',
#  'AC007391.2',
#  'AC007392.3',
#  'AC007392.4',
#  'AC007395.3',
#  'AC007403.2',
#  'AC007403.3',
#  'AC007405.4',
#  'AC007405.6',
#  'AC007405.8',
#  'AC007422.1',
#  'AC007461.2',
#  'AC007463.2',
#  'AC007556.3',
#  'AC007557.1',
#  'AC007557.2',
#  'AC007557.3',
#  'AC007557.4',
#  'AC007563.1',
#  'AC007563.3',
#  'AC007563.5',
#  'AC007566.10',
#  'AC007620.3',
#  'AC007631.1',
#  'AC007652.1',
#  'AC007679.3',
#  'AC007682.1',
#  'AC007740.1',
#  'AC007743.1',
#  'AC007750.5',
#  'AC007773.2',
#  'AC007787.2',
#  'AC007795.1',
#  'AC007796.1',
#  'AC007879.1',
#  'AC007879.2',
#  'AC007879.3',
#  'AC007879.4',
#  'AC007879.5',
#  'AC007879.6',
#  'AC007879.7',
#  'AC007880.1',
#  'AC007948.1',
#  'AC007950.1',
#  'AC007952.4',
#  'AC007952.6',
#  'AC007966.1',
#  'AC008060.5',
#  'AC008060.7',
#  'AC008060.8',
#  'AC008063.2',
#  'AC008063.3',
#  'AC008067.2',
#  'AC008069.1',
#  'AC008073.7',
#  'AC008073.9',
#  'AC008074.3',
#  'AC008074.4',
#  'AC008079.9',
#  'AC008088.4',
#  'AC008154.4',
#  'AC008154.5',
#  'AC008163.4',
#  'AC008175.1',
#  'AC008268.1',
#  'AC008269.2',
#  'AC008271.1',
#  'AC008277.1',
#  'AC008278.2',
#  'AC008278.3',
#  'AC008281.1',
#  'AC008440.10',
#  'AC008440.5',
#  'AC008592.4',
#  'AC008592.7',
#  'AC008592.8',
#  'AC008686.1',
#  'AC008691.1',
#  'AC008694.3',
#  'AC008697.1',
#  'AC008703.1',
#  'AC008746.12',
#  'AC008746.3',
#  'AC008753.4',
#  'AC008753.6',
#  'AC008781.7',
#  'AC008834.1',
#  'AC008914.1',
#  'AC008937.2',
#  'AC008937.3',
#  'AC008940.1',
#  'AC008991.1',
#  'AC008992.1',
#  'AC009005.2',
#  'AC009014.3',
#  'AC009095.4',
#  'AC009110.1',
#  'AC009120.10',
#  'AC009120.4',
#  'AC009120.5',
#  'AC009133.12',
#  'AC009133.15',
#  'AC009133.17',
#  'AC009133.21',
#  'AC009134.1',
#  'AC009158.1',
#  'AC009166.5',
#  'AC009227.2',
#  'AC009227.3',
#  'AC009228.1',
#  'AC009229.5',
#  'AC009229.6',
#  'AC009236.2',
#  'AC009262.2',
#  'AC009276.4',
#  'AC009299.2',
#  'AC009299.3',
#  'AC009303.1',
#  'AC009305.1',
#  'AC009312.1',
#  'AC009313.1',
#  'AC009365.4',
#  'AC009403.2',
#  'AC009404.2',
#  'AC009410.1',
#  'AC009411.1',
#  'AC009411.2',
#  'AC009473.1',
#  'AC009478.1',
#  'AC009480.3',
#  'AC009487.4',
#  'AC009495.2',
#  'AC009495.3',
#  'AC009495.4',
#  'AC009498.1',
#  'AC009501.4',
#  'AC009502.4',
#  'AC009505.2',
#  'AC009505.4',
#  'AC009506.1',
#  'AC009508.1',
#  'AC009518.4',
#  'AC009518.8',
#  'AC009531.2',
#  'AC009542.2',
#  'AC009784.3',
#  'AC009878.2',
#  'AC009892.10',
#  'AC009948.5',
#  'AC009950.2',
#  'AC009955.8',
#  'AC009961.3',
#  'AC009965.2',
#  'AC009970.1',
#  'AC009977.1',
#  'AC010082.2',
#  'AC010084.1',
#  'AC010091.1',
#  'AC010096.1',
#  'AC010096.2',
#  'AC010105.1',
#  'AC010127.3',
#  'AC010132.10',
#  'AC010136.2',
#  'AC010145.4',
#  'AC010149.4',
#  'AC010226.4',
#  'AC010468.2',
#  'AC010504.2',
#  'AC010524.2',
#  'AC010524.4',
#  'AC010525.4',
#  'AC010547.9',
#  'AC010641.1',
#  'AC010642.1',
#  'AC010646.3',
#  'AC010649.1',
#  'AC010723.1',
#  'AC010729.2',
#  'AC010729.3',
#  'AC010731.2',
#  'AC010731.3',
#  'AC010731.4',
#  'AC010744.1',
#  'AC010745.1',
#  'AC010745.2',
#  'AC010745.3',
#  'AC010745.4',
#  'AC010746.3',
#  'AC010761.10',
#  'AC010761.13',
#  'AC010761.14',
#  'AC010761.6',
#  'AC010761.8',
#  'AC010761.9',
#  'AC010880.1',
#  'AC010883.5',
#  'AC010884.1',
#  'AC010890.1',
#  'AC010891.2',
#  'AC010894.3',
#  'AC010894.5',
#  'AC010907.2',
#  'AC010907.5',
#  'AC010967.2',
#  'AC010967.3',
#  'AC010969.1',
#  'AC010971.1',
#  'AC010974.3',
#  'AC010975.1',
#  'AC010976.2',
#  'AC010982.2',
#  'AC010983.1',
#  'AC010987.5',
#  'AC010987.6',
#  'AC011043.1',
#  'AC011193.1',
#  'AC011196.3',
#  'AC011239.1',
#  'AC011243.1',
#  'AC011247.3',
#  'AC011284.3',
#  'AC011286.1',
#  'AC011288.2',
#  'AC011290.4',
#  'AC011294.3',
#  'AC011298.2',
#  'AC011306.1',
#  'AC011343.1',
#  'AC011366.3',
#  'AC011513.4',
#  'AC011516.1',
#  'AC011516.2',
#  'AC011518.1',
#  'AC011518.2',
#  'AC011523.2',
#  'AC011524.1',
#  'AC011524.2',
#  'AC011524.3',
#  'AC011525.2',
#  'AC011525.4',
#  'AC011530.4',
#  'AC011625.1',
#  'AC011648.1',
#  'AC011718.2',
#  'AC011718.3',
#  'AC011738.4',
#  'AC011747.3',
#  'AC011747.4',
#  'AC011747.6',
#  'AC011752.1',
#  'AC011841.1',
#  'AC011893.3',
#  'AC011897.2',
#  'AC011899.10',
#  'AC011899.9',
#  'AC011901.2',
#  'AC011995.1',
#  'AC011995.3',
#  'AC011997.1',
#  'AC012065.4',
#  'AC012074.2',
#  'AC012075.2',
#  'AC012123.1',
#  'AC012307.2',
#  'AC012314.20',
#  'AC012314.8',
#  'AC012322.1',
#  'AC012354.6',
#  'AC012358.7',
#  'AC012358.8',
#  'AC012360.4',
#  'AC012360.6',
#  'AC012361.1',
#  'AC012363.13',
#  'AC012363.4',
#  'AC012368.1',
#  'AC012370.3',
#  'AC012442.6',
#  'AC012445.1',
#  'AC012451.1',
#  'AC012456.3',
#  'AC012456.4',
#  'AC012462.1',
#  'AC012462.2',
#  'AC012462.3',
#  'AC012485.2',
#  'AC012494.1',
#  'AC012499.1',
#  'AC012506.1',
#  'AC012506.2',
#  'AC012506.3',
#  'AC012506.4',
#  'AC012507.3',
#  'AC012507.4',
#  'AC012513.6',
#  'AC012531.25',
#  'AC012593.1',
#  'AC012594.1',
#  'AC012613.2',
#  'AC012668.1',
#  'AC012668.2',
#  'AC012668.3',
#  'AC013248.2',
#  'AC013264.2',
#  'AC013269.3',
#  'AC013269.4',
#  'AC013269.5',
#  'AC013275.2',
#  'AC013401.1',
#  'AC013401.2',
#  'AC013402.3',
#  'AC013402.4',
#  'AC013402.5',
#  'AC013436.6',
#  'AC013448.1',
#  'AC013448.2',
#  'AC013463.2',
#  'AC013472.4',
#  'AC013480.2',
#  'AC013727.1',
#  'AC013727.2',
#  'AC013733.3',
#  'AC013733.4',
#  'AC015688.3',
#  'AC015691.13',
#  'AC015849.12',
#  'AC015849.16',
#  'AC015849.19',
#  'AC015849.2',
#  'AC015922.6',
#  'AC015923.1',
#  'AC015933.2',
#  'AC015936.3',
#  'AC015969.3',
#  'AC015971.2',
#  'AC015977.6',
#  'AC015987.1',
#  'AC016292.1',
#  'AC016582.2',
#  'AC016629.3',
#  'AC016644.1',
#  'AC016682.1',
#  'AC016683.5',
#  'AC016700.2',
#  'AC016700.5',
#  'AC016710.1',
#  'AC016716.2',
#  'AC016722.3',
#  'AC016722.4',
#  'AC016723.4',
#  'AC016730.1',
#  'AC016735.1',
#  'AC016735.2',
#  'AC016735.3',
#  'AC016738.3',
#  'AC016738.4',
#  'AC016745.3',
#  'AC016751.2',
#  'AC016751.3',
#  'AC016768.1',
#  'AC016831.7',
#  'AC016903.1',
#  'AC016903.2',
#  'AC016907.3',
#  'AC016909.1',
#  'AC016910.1',
#  'AC016912.3',
#  'AC016994.2',
#  'AC016995.3',
#  'AC016999.2',
#  'AC017002.1',
#  'AC017002.2',
#  'AC017002.4',
#  'AC017006.2',
#  'AC017006.3',
#  'AC017048.1',
#  'AC017048.2',
#  'AC017053.1',
#  'AC017060.1',
#  'AC017074.1',
#  'AC017074.2',
#  'AC017081.1',
#  'AC017101.10',
#  'AC017104.2',
#  'AC018359.1',
#  'AC018359.3',
#  'AC018462.2',
#  'AC018495.3',
#  'AC018512.1',
#  'AC018643.4',
#  'AC018647.3',
#  'AC018685.1',
#  'AC018685.2',
#  'AC018693.6',
#  'AC018717.1',
#  'AC018730.4',
#  'AC018731.3',
#  'AC018737.3',
#  'AC018742.1',
#  'AC018755.17',
#  'AC018766.4',
#  'AC018766.6',
#  'AC018799.1',
#  'AC018804.3',
#  'AC018816.3',
#  'AC018832.1',
#  'AC018866.1',
#  'AC018867.1',
#  'AC018878.3',
#  'AC018890.4',
#  'AC018890.6',
#  'AC019048.1',
#  'AC019055.1',
#  'AC019064.1',
#  'AC019117.1',
#  'AC019117.2',
#  'AC019118.3',
#  'AC019118.4',
#  'AC019172.2',
#  'AC019181.2',
#  'AC019186.1',
#  'AC019206.1',
#  'AC019330.1',
#  'AC019349.5',
#  'AC020571.3',
#  'AC020594.5',
#  'AC020595.1',
#  'AC020743.2',
#  'AC020743.3',
#  'AC020743.4',
#  'AC020956.3',
#  'AC021021.2',
#  'AC021188.4',
#  'AC021218.2',
#  'AC021224.1',
#  'AC022007.5',
#  'AC022154.7',
#  'AC022173.2',
#  'AC022182.1',
#  'AC022182.3',
#  'AC022201.4',
#  'AC022201.5',
#  'AC022210.1',
#  'AC022486.1',
#  'AC022816.2',
#  'AC022819.2',
#  'AC023115.2',
#  'AC023115.4',
#  'AC023128.1',
#  'AC023137.2',
#  'AC023347.1',
#  'AC023469.1',
#  'AC023469.2',
#  'AC023481.1',
#  'AC023590.1',
#  'AC023669.1',
#  'AC024028.1',
#  'AC024084.1',
#  'AC024132.1',
#  'AC024560.2',
#  'AC024592.12',
#  'AC024592.9',
#  'AC024704.2',
#  'AC025016.1',
#  'AC025165.8',
#  'AC025171.1',
#  'AC025263.3',
#  'AC025335.1',
#  'AC025442.3',
#  'AC025811.3',
#  'AC025918.2',
#  'AC026150.8',
#  'AC026167.1',
#  'AC026188.1',
#  'AC026202.3',
#  'AC026202.5',
#  'AC026471.6',
#  'AC026904.1',
#  'AC027119.1',
#  'AC027601.1',
#  'AC034110.1',
#  'AC034187.2',
#  'AC034228.2',
#  'AC034228.3',
#  'AC034228.4',
#  'AC034243.1',
#  'AC037445.1',
#  'AC037459.4',
#  'AC046143.3',
#  'AC053503.11',
#  'AC053503.4',
#  'AC053503.6',
#  'AC055764.1',
#  'AC060834.3',
#  'AC061961.2',
#  'AC061992.2',
#  'AC062017.1',
#  'AC062020.1',
#  'AC062020.2',
#  'AC062021.1',
#  'AC062028.1',
#  'AC062029.1',
#  'AC062031.1',
#  'AC062032.1',
#  'AC063976.3',
#  'AC064834.1',
#  'AC064834.2',
#  'AC064834.3',
#  'AC064865.1',
#  'AC064871.3',
#  'AC064874.1',
#  'AC067945.2',
#  'AC067956.1',
#  'AC067959.1',
#  'AC067960.1',
#  'AC067961.1',
#  'AC067968.3',
#  'AC067969.1',
#  'AC067969.2',
#  'AC068057.1',
#  'AC068134.6',
#  'AC068134.8',
#  ...]

# %%
sn_adata = sn_adata[:, genes_to_keep]
sc_adata = sc_adata[:, genes_to_keep]
sc_adata_test = sc_adata_test[:, genes_to_keep]

# %%
sc_adata_test.obs["deconvolution"] = "pseudobulks"
sc_adata.obs["deconvolution"] = "reference"
sn_adata.obs["deconvolution"] = "reference"
# Out:
# /projects/aivich@xsede.org/code-server/tmp/ipykernel_900733/770530534.py:1: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   sc_adata_test.obs["deconvolution"] = "pseudobulks"
# /projects/aivich@xsede.org/code-server/tmp/ipykernel_900733/770530534.py:2: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   sc_adata.obs["deconvolution"] = "reference"
# /projects/aivich@xsede.org/code-server/tmp/ipykernel_900733/770530534.py:3: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   sn_adata.obs["deconvolution"] = "reference"

# %% [markdown]
# QC:

# %%
print(sn_adata)
print(sc_adata)
print(sc_adata_test)
# Out:
# AnnData object with n_obs × n_vars = 9857 × 30316
#     obs: 'data_type', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'cell_types', 'deconvolution'
#     var: 'gene_ids', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
# AnnData object with n_obs × n_vars = 4438 × 30316
#     obs: 'data_type', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'cell_types', 'deconvolution'
#     var: 'gene_ids', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
# AnnData object with n_obs × n_vars = 4230 × 30316
#     obs: 'data_type', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'cell_types', 'deconvolution'
#     var: 'gene_ids', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %%
maps = {
    "dendritic cell": "Dendritic Cells",
    "endothelial cell": "Endothelial Cells",
    "immature NK T cell": "Immature NK T Cells",
    "monocyte": "Monocytes",
    "preadipocyte": "Preadipocytes",
    "T cell": "T Cells",
    "Endothelial cell": "Endothelial Cells",
    "T cell": "T Cells",
    "Macrophage": "Macrophages",
    "macrophage": "Macrophages",
    "Hepatocyte": "Hepatocytes",
    "Epithelial cell": "Epithelial Cells",
}
sn_adata.obs.cell_types = sn_adata.obs.cell_types.replace(maps)
sc_adata.obs.cell_types = sc_adata.obs.cell_types.replace(maps)
sc_adata_test.obs.cell_types = sc_adata_test.obs.cell_types.replace(maps)

# %%
print(sn_adata.obs.cell_types.value_counts())
print(sc_adata.obs.cell_types.value_counts())
print(sc_adata_test.obs.cell_types.value_counts())
# Out:
# cell_types
# Epithelial Cells     6964
# Macrophages          1153
# T Cells               782
# Hepatocytes           437
# Endothelial Cells     387
# Fibroblast            121
# B cell                 13
# Name: count, dtype: int64
# cell_types
# T Cells              2571
# Macrophages           778
# Epithelial Cells      605
# Endothelial Cells     231
# B cell                124
# Hepatocytes            72
# Fibroblast             57
# Name: count, dtype: int64
# cell_types
# Epithelial Cells     3143
# T Cells               562
# Macrophages           223
# Endothelial Cells     163
# Hepatocytes            50
# Fibroblast             47
# B cell                 42
# Name: count, dtype: int64

# %%
all_adatas = sc.concat([sn_adata, sc_adata_test, sc_adata])
# Out:
# /projects/aivich@xsede.org/.conda/envs/env_deconv/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
path = f"{os.getcwd()}/../data/{res_name}/"
# saving for later adata as anndata without normalization
adata_path = os.path.join(path, f"sc_sn_{res_name}_processed.h5ad")
adata_path = Path(adata_path)
all_adatas.write_h5ad(adata_path)
